# %%
#importing libraries

import spacy
import pandas as pd
import random

# %%
#python -m spacy download en

nlp = spacy.load('en')

# %%
type(nlp)
# Out:
# spacy.lang.en.English

# %% [markdown]
# ## Loading the dataset

# %%
tweets = pd.read_csv('/Users/ankurrastogi/Chetna/Practise/Kaggle/Tweets_spaCy/archive/justdoit_tweets_2018_09_07_2.csv')

# %%
tweets.head()
# Out:
#    tweet_contributors                                  tweet_coordinates  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN  {'type': 'Point', 'coordinates': [-86.45594032...
# 4                 NaN                                                NaN
#
#                  tweet_created_at tweet_display_text_range  \
# 0  Fri Sep 07 16:25:06 +0000 2018                  [0, 75]
# 1  Fri Sep 07 16:24:59 +0000 2018                 [0, 237]
# 2  Fri Sep 07 16:24:50 +0000 2018                 [0, 176]
# 3  Fri Sep 07 16:24:44 +0000 2018                  [0, 88]
# 4  Fri Sep 07 16:24:39 +0000 2018                 [0, 132]
#
#                                       tweet_entities  \
# 0  {'hashtags': [{'text': 'quote', 'indices': [47...
# 1  {'hashtags': [{'text': 'hero', 'indices': [90,...
# 2  {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 3  {'hashtags': [{'text': 'kapernickeffect', 'ind...
# 4  {'hashtags': [{'text': 'shaquem', 'indices': [...
#
#                              tweet_extended_entities  tweet_favorite_count  \
# 0  {'media': [{'id': 1038100853872197632, 'id_str...                     0
# 1                                                NaN                     0
# 2  {'media': [{'id': 1038100773396041728, 'id_str...                     0
# 3                                                NaN                     0
# 4  {'media': [{'id': 1038100736595255296, 'id_str...                     0
#
#    tweet_favorited                                    tweet_full_text  \
# 0            False  Done is better than perfect. — Sheryl Sandberg...
# 1            False  Shout out to the Great Fire Department and the...
# 2            False  There are some AMAZINGLY hilarious Nike Ad mem...
# 3            False  #kapernickeffect #swoosh #justdoit @ Lucas Bis...
# 4            False  One Hand, One Dream: The Shaquem Griffin Story...
#
#                                            tweet_geo  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
# 3  {'type': 'Point', 'coordinates': [35.85402047,...  ...
# 4                                                NaN  ...
#
#    user_profile_text_color  user_profile_use_background_image user_protected  \
# 0                   333333                               True          False
# 1                   333333                               True          False
# 2                   050505                               True          False
# 3                   333333                               True          False
# 4                   1A1E1A                               True          False
#
#    user_screen_name  user_statuses_count  user_time_zone  \
# 0     UltraYOUwoman              91870.0             NaN
# 1         yungcutup             618822.0             NaN
# 2       rachelbogle              48075.0             NaN
# 3       ErvGotti609               1983.0             NaN
# 4      NoLuckNeeded              24989.0             NaN
#
#    user_translator_type                 user_url user_utc_offset user_verified
# 0                  none  https://t.co/jGlJswxjwS             NaN         False
# 1                  none   http://t.co/lVm8vfDbfO             NaN         False
# 2                  none  https://t.co/g9exqgZp9x             NaN          True
# 3                  none                      NaN             NaN         False
# 4                  none   http://t.co/MMGF9RfLz0             NaN         False
#
# [5 rows x 72 columns]

# %%
tweets.shape
# Out:
# (5089, 72)

# %% [markdown]
# #### For our NLP task, we are only interested in tweets_full_text.

# %%
tweets['tweet_full_text'][:20]
# Out:
# 0     Done is better than perfect. — Sheryl Sandberg...
# 1     Shout out to the Great Fire Department and the...
# 2     There are some AMAZINGLY hilarious Nike Ad mem...
# 3     #kapernickeffect #swoosh #justdoit @ Lucas Bis...
# 4     One Hand, One Dream: The Shaquem Griffin Story...
# 5     @realDonaldTrump It's time for me to stock up ...
# 6     Why won't Trump protect our elections?  Think ...
# 7     @Nike good job on shaking the whole world, i s...
# 8     GREAT way to meet good people...wearing your N...
# 9     Lead,Trade and Succeed with ICM\nPlease retwee...
# 10    My favorites so far #JustDoIt https://t.co/zY7...
# 11    Colin Kaepernick's business partner @Nike send...
# 12    @CSPensions Why be a cat when you can be a lio...
# 13    @realDonaldTrump They were thinking history wi...
# 14    @RepAdamSchiff Go ahead @RepAdamSchiff   #Just...
# 15    Why be a cat when you can be a lion. #JustDoIt...
# 16    #socialism be like me and #JustDoIt because ya...
# 17    Hey @Nike I stood for our country. I served my...
# 18    I’ve seen a lot of memes re #JustDoIt but this...
# 19    Abortion stops a beating heart. Just imagine a...
# Name: tweet_full_text, dtype: object

# %% [markdown]
# ### Random 20 tweets

# %%
#random tweets
random.seed(1024)

random_tweets = tweets['tweet_full_text'][random.sample(range(1,5000), 20)]
random_tweets
# Out:
# 157     Never stop moving. \n\nDon’t ask if your dream...
# 3961                @Nike what an inspiring ad. #JustDoIt
# 3191    Question if you see a white person wearing Nik...
# 2648    @Jim_Jordan We would love to see the FISA appl...
# 4259    ✊🏾#nike #justdoit \nNike probably doesn’t care...
# 823     Change your focus America. #JustDoIt https://t...
# 3647    There will be a number of people that see the ...
# 4202    Falcons Eagles  #Football  #JustDoIt  #ATLvsPH...
# 2998    @Reuters Here comes the WH distraction.   #Imp...
# 3022    Coulter: Trump doesn't need Congress to build ...
# 3182    My brand new @Nikecourt Air Zoom Vapor X @nike...
# 787     “Don’t ask if your dreams are crazy, ask if it...
# 1149    @Nike Hire a worthless, no talent. America hat...
# 838     kudos to #Nike for realizing #ColinKaepernick ...
# 3356    Self LOVE and Self DISCIPLINE means you forgo ...
# 1271    Why doesn’t the “Anonymous”author of the #Fail...
# 3574          Matt Ryan throw it to Julio #JustDoIt #Nike
# 3883    There it go!!!!!!! Now I can stop watching the...
# 3656    @Nike “stand for something” it is called the F...
# 4301    ✊🏾 #Repost mgnm_opus\n・・・\n👑 This message is a...
# Name: tweet_full_text, dtype: object

# %% [markdown]
# ### Combining text as nlp variable created using spaCy will only use str

# %%
#combined text

combined_text = str(random_tweets)
combined_text
# len(combined_text)
# type(combined_text)
# Out:
# "157     Never stop moving. \\n\\nDon’t ask if your dream...\n3961                @Nike what an inspiring ad. #JustDoIt\n3191    Question if you see a white person wearing Nik...\n2648    @Jim_Jordan We would love to see the FISA appl...\n4259    ✊🏾#nike #justdoit \\nNike probably doesn’t care...\n823     Change your focus America. #JustDoIt https://t...\n3647    There will be a number of people that see the ...\n4202    Falcons Eagles  #Football  #JustDoIt  #ATLvsPH...\n2998    @Reuters Here comes the WH distraction.   #Imp...\n3022    Coulter: Trump doesn't need Congress to build ...\n3182    My brand new @Nikecourt Air Zoom Vapor X @nike...\n787     “Don’t ask if your dreams are crazy, ask if it...\n1149    @Nike Hire a worthless, no talent. America hat...\n838     kudos to #Nike for realizing #ColinKaepernick ...\n3356    Self LOVE and Self DISCIPLINE means you forgo ...\n1271    Why doesn’t the “Anonymous”author of the #Fail...\n3574          Matt Ryan throw it to Julio #JustDoIt #Nike\n3883    There it go!!!!!!! Now I can stop watching the...\n3656    @Nike “stand for something” it is called the F...\n4301    ✊🏾 #Repost mgnm_opus\\n・・・\\n👑 This message is a...\nName: tweet_full_text, dtype: object"

# %%
doc = nlp(combined_text)
doc
# Out:
# 157     Never stop moving. \n\nDon’t ask if your dream...
# 3961                @Nike what an inspiring ad. #JustDoIt
# 3191    Question if you see a white person wearing Nik...
# 2648    @Jim_Jordan We would love to see the FISA appl...
# 4259    ✊🏾#nike #justdoit \nNike probably doesn’t care...
# 823     Change your focus America. #JustDoIt https://t...
# 3647    There will be a number of people that see the ...
# 4202    Falcons Eagles  #Football  #JustDoIt  #ATLvsPH...
# 2998    @Reuters Here comes the WH distraction.   #Imp...
# 3022    Coulter: Trump doesn't need Congress to build ...
# 3182    My brand new @Nikecourt Air Zoom Vapor X @nike...
# 787     “Don’t ask if your dreams are crazy, ask if it...
# 1149    @Nike Hire a worthless, no talent. America hat...
# 838     kudos to #Nike for realizing #ColinKaepernick ...
# 3356    Self LOVE and Self DISCIPLINE means you forgo ...
# 1271    Why doesn’t the “Anonymous”author of the #Fail...
# 3574          Matt Ryan throw it to Julio #JustDoIt #Nike
# 3883    There it go!!!!!!! Now I can stop watching the...
# 3656    @Nike “stand for something” it is called the F...
# 4301    ✊🏾 #Repost mgnm_opus\n・・・\n👑 This message is a...
# Name: tweet_full_text, dtype: object

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %% [markdown]
# ### Naive approach for splitting

# %%
#tokenization using split as space
doc.text.split()
# Out:
# ['157',
#  'Never',
#  'stop',
#  'moving.',
#  '\\n\\nDon’t',
#  'ask',
#  'if',
#  'your',
#  'dream...',
#  '3961',
#  '@Nike',
#  'what',
#  'an',
#  'inspiring',
#  'ad.',
#  '#JustDoIt',
#  '3191',
#  'Question',
#  'if',
#  'you',
#  'see',
#  'a',
#  'white',
#  'person',
#  'wearing',
#  'Nik...',
#  '2648',
#  '@Jim_Jordan',
#  'We',
#  'would',
#  'love',
#  'to',
#  'see',
#  'the',
#  'FISA',
#  'appl...',
#  '4259',
#  '✊🏾#nike',
#  '#justdoit',
#  '\\nNike',
#  'probably',
#  'doesn’t',
#  'care...',
#  '823',
#  'Change',
#  'your',
#  'focus',
#  'America.',
#  '#JustDoIt',
#  'https://t...',
#  '3647',
#  'There',
#  'will',
#  'be',
#  'a',
#  'number',
#  'of',
#  'people',
#  'that',
#  'see',
#  'the',
#  '...',
#  '4202',
#  'Falcons',
#  'Eagles',
#  '#Football',
#  '#JustDoIt',
#  '#ATLvsPH...',
#  '2998',
#  '@Reuters',
#  'Here',
#  'comes',
#  'the',
#  'WH',
#  'distraction.',
#  '#Imp...',
#  '3022',
#  'Coulter:',
#  'Trump',
#  "doesn't",
#  'need',
#  'Congress',
#  'to',
#  'build',
#  '...',
#  '3182',
#  'My',
#  'brand',
#  'new',
#  '@Nikecourt',
#  'Air',
#  'Zoom',
#  'Vapor',
#  'X',
#  '@nike...',
#  '787',
#  '“Don’t',
#  'ask',
#  'if',
#  'your',
#  'dreams',
#  'are',
#  'crazy,',
#  'ask',
#  'if',
#  'it...',
#  '1149',
#  '@Nike',
#  'Hire',
#  'a',
#  'worthless,',
#  'no',
#  'talent.',
#  'America',
#  'hat...',
#  '838',
#  'kudos',
#  'to',
#  '#Nike',
#  'for',
#  'realizing',
#  '#ColinKaepernick',
#  '...',
#  '3356',
#  'Self',
#  'LOVE',
#  'and',
#  'Self',
#  'DISCIPLINE',
#  'means',
#  'you',
#  'forgo',
#  '...',
#  '1271',
#  'Why',
#  'doesn’t',
#  'the',
#  '“Anonymous”author',
#  'of',
#  'the',
#  '#Fail...',
#  '3574',
#  'Matt',
#  'Ryan',
#  'throw',
#  'it',
#  'to',
#  'Julio',
#  '#JustDoIt',
#  '#Nike',
#  '3883',
#  'There',
#  'it',
#  'go!!!!!!!',
#  'Now',
#  'I',
#  'can',
#  'stop',
#  'watching',
#  'the...',
#  '3656',
#  '@Nike',
#  '“stand',
#  'for',
#  'something”',
#  'it',
#  'is',
#  'called',
#  'the',
#  'F...',
#  '4301',
#  '✊🏾',
#  '#Repost',
#  'mgnm_opus\\n・・・\\n👑',
#  'This',
#  'message',
#  'is',
#  'a...',
#  'Name:',
#  'tweet_full_text,',
#  'dtype:',
#  'object']

# %% [markdown]
# #### Naive approach just breaks the sentence into parts based on the splitting criteria.

# %% [markdown]
# ## Tokenization using spaCy

# %%
[token.orth_ for token in doc]
# Out:
# ['157',
#  '    ',
#  'Never',
#  'stop',
#  'moving',
#  '.',
#  '\\n\\nDon’t',
#  'ask',
#  'if',
#  'your',
#  'dream',
#  '...',
#  '\n',
#  '3961',
#  '               ',
#  '@Nike',
#  'what',
#  'an',
#  'inspiring',
#  'ad',
#  '.',
#  '#',
#  'JustDoIt',
#  '\n',
#  '3191',
#  '   ',
#  'Question',
#  'if',
#  'you',
#  'see',
#  'a',
#  'white',
#  'person',
#  'wearing',
#  'Nik',
#  '...',
#  '\n',
#  '2648',
#  '   ',
#  '@Jim_Jordan',
#  'We',
#  'would',
#  'love',
#  'to',
#  'see',
#  'the',
#  'FISA',
#  'appl',
#  '...',
#  '\n',
#  '4259',
#  '   ',
#  '✊',
#  '🏾#nike',
#  '#',
#  'justdoit',
#  '\\nNike',
#  'probably',
#  'does',
#  'n’t',
#  'care',
#  '...',
#  '\n',
#  '823',
#  '    ',
#  'Change',
#  'your',
#  'focus',
#  'America',
#  '.',
#  '#',
#  'JustDoIt',
#  'https://t',
#  '...',
#  '\n',
#  '3647',
#  '   ',
#  'There',
#  'will',
#  'be',
#  'a',
#  'number',
#  'of',
#  'people',
#  'that',
#  'see',
#  'the',
#  '...',
#  '\n',
#  '4202',
#  '   ',
#  'Falcons',
#  'Eagles',
#  ' ',
#  '#',
#  'Football',
#  ' ',
#  '#',
#  'JustDoIt',
#  ' ',
#  '#',
#  'ATLvsPH',
#  '...',
#  '\n',
#  '2998',
#  '   ',
#  '@Reuters',
#  'Here',
#  'comes',
#  'the',
#  'WH',
#  'distraction',
#  '.',
#  '  ',
#  '#',
#  'Imp',
#  '...',
#  '\n',
#  '3022',
#  '   ',
#  'Coulter',
#  ':',
#  'Trump',
#  'does',
#  "n't",
#  'need',
#  'Congress',
#  'to',
#  'build',
#  '...',
#  '\n',
#  '3182',
#  '   ',
#  'My',
#  'brand',
#  'new',
#  '@Nikecourt',
#  'Air',
#  'Zoom',
#  'Vapor',
#  'X',
#  '@nike',
#  '...',
#  '\n',
#  '787',
#  '    ',
#  '“',
#  'Do',
#  'n’t',
#  'ask',
#  'if',
#  'your',
#  'dreams',
#  'are',
#  'crazy',
#  ',',
#  'ask',
#  'if',
#  'it',
#  '...',
#  '\n',
#  '1149',
#  '   ',
#  '@Nike',
#  'Hire',
#  'a',
#  'worthless',
#  ',',
#  'no',
#  'talent',
#  '.',
#  'America',
#  'hat',
#  '...',
#  '\n',
#  '838',
#  '    ',
#  'kudos',
#  'to',
#  '#',
#  'Nike',
#  'for',
#  'realizing',
#  '#',
#  'ColinKaepernick',
#  '...',
#  '\n',
#  '3356',
#  '   ',
#  'Self',
#  'LOVE',
#  'and',
#  'Self',
#  'DISCIPLINE',
#  'means',
#  'you',
#  'forgo',
#  '...',
#  '\n',
#  '1271',
#  '   ',
#  'Why',
#  'does',
#  'n’t',
#  'the',
#  '“',
#  'Anonymous”author',
#  'of',
#  'the',
#  '#',
#  'Fail',
#  '...',
#  '\n',
#  '3574',
#  '         ',
#  'Matt',
#  'Ryan',
#  'throw',
#  'it',
#  'to',
#  'Julio',
#  '#',
#  'JustDoIt',
#  '#',
#  'Nike',
#  '\n',
#  '3883',
#  '   ',
#  'There',
#  'it',
#  'go',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  'Now',
#  'I',
#  'can',
#  'stop',
#  'watching',
#  'the',
#  '...',
#  '\n',
#  '3656',
#  '   ',
#  '@Nike',
#  '“',
#  'stand',
#  'for',
#  'something',
#  '”',
#  'it',
#  'is',
#  'called',
#  'the',
#  'F',
#  '...',
#  '\n',
#  '4301',
#  '   ',
#  '✊',
#  '🏾',
#  '#',
#  'Repost',
#  'mgnm_opus\\n・・・\\n',
#  '👑',
#  'This',
#  'message',
#  'is',
#  'a',
#  '...',
#  '\n',
#  'Name',
#  ':',
#  'tweet_full_text',
#  ',',
#  'dtype',
#  ':',
#  'object']

# %% [markdown]
# #### Methods with underscore suffix in spaCy returns strings whereas methods without underscore suffix returns numbers

# %%
[(token.orth_, token.orth) for token in doc if not token.is_punct | token.is_space | token.is_stop]
# Out:
# [('157', 14219973349862421882),
#  ('stop', 8369783199685603043),
#  ('moving', 5469515476653199844),
#  ('\\n\\nDon’t', 3073864672632201942),
#  ('ask', 203487227105936704),
#  ('dream', 15068273739048504437),
#  ('3961', 14859694932817653484),
#  ('@Nike', 5247431814175727194),
#  ('inspiring', 13959827168227632684),
#  ('ad', 2684585717478260826),
#  ('JustDoIt', 9344526255527223624),
#  ('3191', 16401104065649945982),
#  ('Question', 14363772479120787699),
#  ('white', 16857069738040043275),
#  ('person', 14800503047316267216),
#  ('wearing', 14346153148292249925),
#  ('Nik', 13801226329647282512),
#  ('2648', 7599300793114082915),
#  ('@Jim_Jordan', 154124950895647725),
#  ('love', 3702023516439754181),
#  ('FISA', 14784500557764967955),
#  ('appl', 14486548703982382384),
#  ('4259', 4023893381634396992),
#  ('✊', 8641612878872982689),
#  ('🏾#nike', 16106677573811388583),
#  ('justdoit', 1620920072761231147),
#  ('\\nNike', 9956095468550846820),
#  ('probably', 8549214374670072303),
#  ('care', 14027581762467160941),
#  ('823', 5519617386052103215),
#  ('Change', 5592985864901179570),
#  ('focus', 12460925685579008443),
#  ('America', 13134984502707718284),
#  ('JustDoIt', 9344526255527223624),
#  ('https://t', 16392215616339226632),
#  ('3647', 5939670392288161035),
#  ('number', 432),
#  ('people', 7593739049417968140),
#  ('4202', 6859641617661182588),
#  ('Falcons', 2261134009783025047),
#  ('Eagles', 8519161867406687538),
#  ('Football', 9774136247952172919),
#  ('JustDoIt', 9344526255527223624),
#  ('ATLvsPH', 7137954081429936161),
#  ('2998', 2048796559703174507),
#  ('@Reuters', 7004387960574449687),
#  ('comes', 10038222706987769888),
#  ('WH', 7684539283388990472),
#  ('distraction', 2226835521114747877),
#  ('Imp', 11058631131069793471),
#  ('3022', 2220116390019727441),
#  ('Coulter', 14381408114861127615),
#  ('Trump', 1134333841961332695),
#  ('need', 478886015463313967),
#  ('Congress', 12671291877092410788),
#  ('build', 15542623189494043735),
#  ('3182', 12517718508848770810),
#  ('brand', 3827899546313821993),
#  ('new', 4753564829687343602),
#  ('@Nikecourt', 2161620736284644949),
#  ('Air', 10266199396556742871),
#  ('Zoom', 205442828555831923),
#  ('Vapor', 1546836434200169719),
#  ('X', 101),
#  ('@nike', 7666116921458289631),
#  ('787', 9218082056587705572),
#  ('ask', 203487227105936704),
#  ('dreams', 17801460365158245434),
#  ('crazy', 16792598155547231470),
#  ('ask', 203487227105936704),
#  ('1149', 15740843450764192527),
#  ('@Nike', 5247431814175727194),
#  ('Hire', 16896451705204278948),
#  ('worthless', 13095714296952392496),
#  ('talent', 17729184473612629068),
#  ('America', 13134984502707718284),
#  ('hat', 14949295185858420483),
#  ('838', 6158781940767354518),
#  ('kudos', 8544758479135825247),
#  ('Nike', 7103763066890493814),
#  ('realizing', 3482743322712588588),
#  ('ColinKaepernick', 11871999882128732298),
#  ('3356', 4259993873796523876),
#  ('Self', 8985479675174290493),
#  ('LOVE', 18437031736592595799),
#  ('Self', 8985479675174290493),
#  ('DISCIPLINE', 17903559587450080042),
#  ('means', 18281114504200336646),
#  ('forgo', 14452957596511091291),
#  ('1271', 3173997569939811398),
#  ('Anonymous”author', 6088940299410014657),
#  ('Fail', 97122986932003843),
#  ('3574', 3428288101242010327),
#  ('Matt', 14076960819181640691),
#  ('Ryan', 13336166577620870933),
#  ('throw', 13223552691897539843),
#  ('Julio', 6546140577747644913),
#  ('JustDoIt', 9344526255527223624),
#  ('Nike', 7103763066890493814),
#  ('3883', 6094275810332084765),
#  ('stop', 8369783199685603043),
#  ('watching', 719528639944397646),
#  ('3656', 9945472115420009375),
#  ('@Nike', 5247431814175727194),
#  ('stand', 16121235759125543490),
#  ('called', 3125235652374451650),
#  ('F', 9148987913859918431),
#  ('4301', 3315446672307893424),
#  ('✊', 8641612878872982689),
#  ('🏾', 17543838021374709631),
#  ('Repost', 2825807053972748733),
#  ('mgnm_opus\\n・・・\\n', 10359096866704796062),
#  ('👑', 18431617554337739177),
#  ('message', 1381057396011922202),
#  ('tweet_full_text', 2739488197769673324),
#  ('dtype', 14573301518653548249),
#  ('object', 17242611361085688134)]

# %% [markdown]
# #### Tokens after removing punctuations, space and stop words

# %%
extracted_tokens = [token.orth_ for token in doc if not token.is_punct | token.is_space | token.is_stop]
extracted_tokens
# Out:
# ['157',
#  'stop',
#  'moving',
#  '\\n\\nDon’t',
#  'ask',
#  'dream',
#  '3961',
#  '@Nike',
#  'inspiring',
#  'ad',
#  'JustDoIt',
#  '3191',
#  'Question',
#  'white',
#  'person',
#  'wearing',
#  'Nik',
#  '2648',
#  '@Jim_Jordan',
#  'love',
#  'FISA',
#  'appl',
#  '4259',
#  '✊',
#  '🏾#nike',
#  'justdoit',
#  '\\nNike',
#  'probably',
#  'care',
#  '823',
#  'Change',
#  'focus',
#  'America',
#  'JustDoIt',
#  'https://t',
#  '3647',
#  'number',
#  'people',
#  '4202',
#  'Falcons',
#  'Eagles',
#  'Football',
#  'JustDoIt',
#  'ATLvsPH',
#  '2998',
#  '@Reuters',
#  'comes',
#  'WH',
#  'distraction',
#  'Imp',
#  '3022',
#  'Coulter',
#  'Trump',
#  'need',
#  'Congress',
#  'build',
#  '3182',
#  'brand',
#  'new',
#  '@Nikecourt',
#  'Air',
#  'Zoom',
#  'Vapor',
#  'X',
#  '@nike',
#  '787',
#  'ask',
#  'dreams',
#  'crazy',
#  'ask',
#  '1149',
#  '@Nike',
#  'Hire',
#  'worthless',
#  'talent',
#  'America',
#  'hat',
#  '838',
#  'kudos',
#  'Nike',
#  'realizing',
#  'ColinKaepernick',
#  '3356',
#  'Self',
#  'LOVE',
#  'Self',
#  'DISCIPLINE',
#  'means',
#  'forgo',
#  '1271',
#  'Anonymous”author',
#  'Fail',
#  '3574',
#  'Matt',
#  'Ryan',
#  'throw',
#  'Julio',
#  'JustDoIt',
#  'Nike',
#  '3883',
#  'stop',
#  'watching',
#  '3656',
#  '@Nike',
#  'stand',
#  'called',
#  'F',
#  '4301',
#  '✊',
#  '🏾',
#  'Repost',
#  'mgnm_opus\\n・・・\\n',
#  '👑',
#  'message',
#  'tweet_full_text',
#  'dtype',
#  'object']

# %%
only_word_tokens = [i for i in extracted_tokens if i.isalpha()]
only_word_tokens
# Out:
# ['stop',
#  'moving',
#  'ask',
#  'dream',
#  'inspiring',
#  'ad',
#  'JustDoIt',
#  'Question',
#  'white',
#  'person',
#  'wearing',
#  'Nik',
#  'love',
#  'FISA',
#  'appl',
#  'justdoit',
#  'probably',
#  'care',
#  'Change',
#  'focus',
#  'America',
#  'JustDoIt',
#  'number',
#  'people',
#  'Falcons',
#  'Eagles',
#  'Football',
#  'JustDoIt',
#  'ATLvsPH',
#  'comes',
#  'WH',
#  'distraction',
#  'Imp',
#  'Coulter',
#  'Trump',
#  'need',
#  'Congress',
#  'build',
#  'brand',
#  'new',
#  'Air',
#  'Zoom',
#  'Vapor',
#  'X',
#  'ask',
#  'dreams',
#  'crazy',
#  'ask',
#  'Hire',
#  'worthless',
#  'talent',
#  'America',
#  'hat',
#  'kudos',
#  'Nike',
#  'realizing',
#  'ColinKaepernick',
#  'Self',
#  'LOVE',
#  'Self',
#  'DISCIPLINE',
#  'means',
#  'forgo',
#  'Fail',
#  'Matt',
#  'Ryan',
#  'throw',
#  'Julio',
#  'JustDoIt',
#  'Nike',
#  'stop',
#  'watching',
#  'stand',
#  'called',
#  'F',
#  'Repost',
#  'message',
#  'dtype',
#  'object']

# %% [markdown]
# ### Tokenization based on sentences

# %%
list(doc.sents)
# Out:
# [157     Never stop moving.,
#  \n\nDon’t ask if your dream...,
#  3961                ,
#  @Nike what an inspiring ad.,
#  #JustDoIt
#  3191    Question if you see a white person wearing Nik...,
#  2648    ,
#  @Jim_Jordan,
#  We would love to see the FISA appl...,
#  4259    ✊,
#  🏾#nike,
#  #justdoit \nNike probably doesn’t care...,
#  823     Change your focus America.,
#  #JustDoIt https://t...,
#  3647    ,
#  There will be a number of people that see the ...,
#  4202    ,
#  Falcons Eagles  ,
#  #Football  ,
#  #JustDoIt  #ATLvsPH...
#  2998    @Reuters,
#  Here comes the WH distraction.   ,
#  #Imp...,
#  3022    ,
#  Coulter: Trump doesn't need Congress to build ...,
#  3182    ,
#  My brand new @Nikecourt Air Zoom Vapor X @nike...,
#  787     ,
#  “Don’t ask if your dreams are crazy, ask if it...,
#  1149    ,
#  @Nike Hire a worthless, no talent.,
#  America hat...,
#  838     kudos to #Nike for realizing #ColinKaepernick ...,
#  3356    ,
#  Self LOVE and Self DISCIPLINE means you forgo ...,
#  1271    ,
#  Why doesn’t the “Anonymous”author of the #Fail...,
#  3574          ,
#  Matt Ryan throw it to Julio #JustDoIt #Nike,
#  3883    ,
#  There it go!!!!!!!,
#  Now I can stop watching the...,
#  3656    ,
#  @Nike “,
#  stand for something”,
#  it is called the F...,
#  4301    ,
#  ✊,
#  🏾 #,
#  Repost mgnm_opus\n・・・\n👑,
#  This message is a...
#  Name:,
#  tweet_full_text, dtype: object]

# %% [markdown]
# ## Lemmatization

# %%
[word.lemma_ for word in doc]
# Out:
# ['157',
#  '    ',
#  'never',
#  'stop',
#  'move',
#  '.',
#  '\\n\\ndon’t',
#  'ask',
#  'if',
#  '-PRON-',
#  'dream',
#  '...',
#  '\n',
#  '3961',
#  '               ',
#  '@Nike',
#  'what',
#  'an',
#  'inspiring',
#  'ad',
#  '.',
#  '#',
#  'JustDoIt',
#  '\n',
#  '3191',
#  '   ',
#  'question',
#  'if',
#  '-PRON-',
#  'see',
#  'a',
#  'white',
#  'person',
#  'wear',
#  'Nik',
#  '...',
#  '\n',
#  '2648',
#  '   ',
#  '@jim_jordan',
#  '-PRON-',
#  'would',
#  'love',
#  'to',
#  'see',
#  'the',
#  'FISA',
#  'appl',
#  '...',
#  '\n',
#  '4259',
#  '   ',
#  '✊',
#  '🏾#nike',
#  '#',
#  'justdoit',
#  '\\nNike',
#  'probably',
#  'do',
#  'not',
#  'care',
#  '...',
#  '\n',
#  '823',
#  '    ',
#  'change',
#  '-PRON-',
#  'focus',
#  'America',
#  '.',
#  '#',
#  'JustDoIt',
#  'https://t',
#  '...',
#  '\n',
#  '3647',
#  '   ',
#  'there',
#  'will',
#  'be',
#  'a',
#  'number',
#  'of',
#  'people',
#  'that',
#  'see',
#  'the',
#  '...',
#  '\n',
#  '4202',
#  '   ',
#  'Falcons',
#  'Eagles',
#  ' ',
#  '#',
#  'football',
#  ' ',
#  '#',
#  'justdoit',
#  ' ',
#  '#',
#  'atlvsph',
#  '...',
#  '\n',
#  '2998',
#  '   ',
#  '@Reuters',
#  'here',
#  'come',
#  'the',
#  'WH',
#  'distraction',
#  '.',
#  '  ',
#  '#',
#  'Imp',
#  '...',
#  '\n',
#  '3022',
#  '   ',
#  'Coulter',
#  ':',
#  'Trump',
#  'do',
#  'not',
#  'need',
#  'Congress',
#  'to',
#  'build',
#  '...',
#  '\n',
#  '3182',
#  '   ',
#  '-PRON-',
#  'brand',
#  'new',
#  '@Nikecourt',
#  'Air',
#  'Zoom',
#  'Vapor',
#  'X',
#  '@nike',
#  '...',
#  '\n',
#  '787',
#  '    ',
#  '"',
#  'do',
#  'not',
#  'ask',
#  'if',
#  '-PRON-',
#  'dream',
#  'be',
#  'crazy',
#  ',',
#  'ask',
#  'if',
#  '-PRON-',
#  '...',
#  '\n',
#  '1149',
#  '   ',
#  '@nike',
#  'hire',
#  'a',
#  'worthless',
#  ',',
#  'no',
#  'talent',
#  '.',
#  'America',
#  'hat',
#  '...',
#  '\n',
#  '838',
#  '    ',
#  'kudo',
#  'to',
#  '#',
#  'Nike',
#  'for',
#  'realize',
#  '#',
#  'ColinKaepernick',
#  '...',
#  '\n',
#  '3356',
#  '   ',
#  'Self',
#  'LOVE',
#  'and',
#  'Self',
#  'DISCIPLINE',
#  'mean',
#  '-PRON-',
#  'forgo',
#  '...',
#  '\n',
#  '1271',
#  '   ',
#  'why',
#  'do',
#  'not',
#  'the',
#  '"',
#  'anonymous”author',
#  'of',
#  'the',
#  '#',
#  'Fail',
#  '...',
#  '\n',
#  '3574',
#  '         ',
#  'Matt',
#  'Ryan',
#  'throw',
#  '-PRON-',
#  'to',
#  'Julio',
#  '#',
#  'JustDoIt',
#  '#',
#  'Nike',
#  '\n',
#  '3883',
#  '   ',
#  'there',
#  '-PRON-',
#  'go',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  'now',
#  '-PRON-',
#  'can',
#  'stop',
#  'watch',
#  'the',
#  '...',
#  '\n',
#  '3656',
#  '   ',
#  '@nike',
#  '"',
#  'stand',
#  'for',
#  'something',
#  '"',
#  '-PRON-',
#  'be',
#  'call',
#  'the',
#  'F',
#  '...',
#  '\n',
#  '4301',
#  '   ',
#  '✊',
#  '🏾',
#  '#',
#  'Repost',
#  'mgnm_opus\\n・・・\\n',
#  '👑',
#  'this',
#  'message',
#  'be',
#  'a',
#  '...',
#  '\n',
#  'name',
#  ':',
#  'tweet_full_text',
#  ',',
#  'dtype',
#  ':',
#  'object']

# %% [markdown]
# ## POS Tagging

# %%
pos_tag = [(word, word.tag_, word.pos_) for word in doc]
pos_tag
# Out:
# [(157, 'CD', 'NUM'),
#  (    , '_SP', 'SPACE'),
#  (Never, 'RB', 'ADV'),
#  (stop, 'VB', 'VERB'),
#  (moving, 'VBG', 'VERB'),
#  (., '.', 'PUNCT'),
#  (\n\nDon’t, 'ADD', 'X'),
#  (ask, 'VB', 'VERB'),
#  (if, 'IN', 'SCONJ'),
#  (your, 'PRP$', 'DET'),
#  (dream, 'NN', 'NOUN'),
#  (..., ':', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (3961, 'CD', 'NUM'),
#  (               , '_SP', 'SPACE'),
#  (@Nike, 'NNP', 'PROPN'),
#  (what, 'WP', 'PRON'),
#  (an, 'DT', 'DET'),
#  (inspiring, 'JJ', 'ADJ'),
#  (ad, 'NN', 'NOUN'),
#  (., '.', 'PUNCT'),
#  (#, 'NN', 'NOUN'),
#  (JustDoIt, 'NNP', 'PROPN'),
#  (, '_SP', 'SPACE'),
#  (3191, 'CD', 'NUM'),
#  (   , '_SP', 'SPACE'),
#  (Question, 'NN', 'NOUN'),
#  (if, 'IN', 'SCONJ'),
#  (you, 'PRP', 'PRON'),
#  (see, 'VBP', 'VERB'),
#  (a, 'DT', 'DET'),
#  (white, 'JJ', 'ADJ'),
#  (person, 'NN', 'NOUN'),
#  (wearing, 'VBG', 'VERB'),
#  (Nik, 'NNP', 'PROPN'),
#  (..., '.', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (2648, 'CD', 'NUM'),
#  (   , '_SP', 'SPACE'),
#  (@Jim_Jordan, 'IN', 'ADP'),
#  (We, 'PRP', 'PRON'),
#  (would, 'MD', 'VERB'),
#  (love, 'VB', 'VERB'),
#  (to, 'TO', 'PART'),
#  (see, 'VB', 'VERB'),
#  (the, 'DT', 'DET'),
#  (FISA, 'NNP', 'PROPN'),
#  (appl, 'NN', 'NOUN'),
#  (..., ':', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (4259, 'CD', 'NUM'),
#  (   , '_SP', 'SPACE'),
#  (✊, 'CD', 'NUM'),
#  (🏾#nike, 'IN', 'ADP'),
#  (#, '$', 'SYM'),
#  (justdoit, 'NNP', 'PROPN'),
#  (\nNike, '.', 'PUNCT'),
#  (probably, 'RB', 'ADV'),
#  (does, 'VBZ', 'AUX'),
#  (n’t, 'RB', 'PART'),
#  (care, 'VB', 'VERB'),
#  (..., ':', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (823, 'CD', 'NUM'),
#  (    , '_SP', 'SPACE'),
#  (Change, 'VB', 'VERB'),
#  (your, 'PRP$', 'DET'),
#  (focus, 'NN', 'NOUN'),
#  (America, 'NNP', 'PROPN'),
#  (., '.', 'PUNCT'),
#  (#, 'NN', 'NOUN'),
#  (JustDoIt, 'NNP', 'PROPN'),
#  (https://t, 'ADD', 'X'),
#  (..., ':', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (3647, 'CD', 'NUM'),
#  (   , '_SP', 'SPACE'),
#  (There, 'EX', 'PRON'),
#  (will, 'MD', 'VERB'),
#  (be, 'VB', 'AUX'),
#  (a, 'DT', 'DET'),
#  (number, 'NN', 'NOUN'),
#  (of, 'IN', 'ADP'),
#  (people, 'NNS', 'NOUN'),
#  (that, 'WDT', 'DET'),
#  (see, 'VBP', 'VERB'),
#  (the, 'DT', 'DET'),
#  (..., ':', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (4202, 'CD', 'NUM'),
#  (   , '_SP', 'SPACE'),
#  (Falcons, 'NNP', 'PROPN'),
#  (Eagles, 'NNPS', 'PROPN'),
#  ( , '_SP', 'SPACE'),
#  (#, '$', 'SYM'),
#  (Football, 'NN', 'NOUN'),
#  ( , '_SP', 'SPACE'),
#  (#, '$', 'SYM'),
#  (JustDoIt, 'NN', 'NOUN'),
#  ( , '_SP', 'SPACE'),
#  (#, 'NN', 'NOUN'),
#  (ATLvsPH, 'NN', 'NOUN'),
#  (..., 'NFP', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (2998, 'CD', 'NUM'),
#  (   , '_SP', 'SPACE'),
#  (@Reuters, 'NNP', 'PROPN'),
#  (Here, 'RB', 'ADV'),
#  (comes, 'VBZ', 'VERB'),
#  (the, 'DT', 'DET'),
#  (WH, 'NNP', 'PROPN'),
#  (distraction, 'NN', 'NOUN'),
#  (., '.', 'PUNCT'),
#  (  , '_SP', 'SPACE'),
#  (#, 'NN', 'NOUN'),
#  (Imp, 'NNP', 'PROPN'),
#  (..., ':', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (3022, 'CD', 'NUM'),
#  (   , '_SP', 'SPACE'),
#  (Coulter, 'NNP', 'PROPN'),
#  (:, ':', 'PUNCT'),
#  (Trump, 'NNP', 'PROPN'),
#  (does, 'VBZ', 'AUX'),
#  (n't, 'RB', 'PART'),
#  (need, 'VB', 'VERB'),
#  (Congress, 'NNP', 'PROPN'),
#  (to, 'TO', 'PART'),
#  (build, 'VB', 'VERB'),
#  (..., ':', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (3182, 'CD', 'NUM'),
#  (   , '_SP', 'SPACE'),
#  (My, 'PRP$', 'DET'),
#  (brand, 'NN', 'NOUN'),
#  (new, 'JJ', 'ADJ'),
#  (@Nikecourt, 'NNP', 'PROPN'),
#  (Air, 'NNP', 'PROPN'),
#  (Zoom, 'NNP', 'PROPN'),
#  (Vapor, 'NNP', 'PROPN'),
#  (X, 'NNP', 'PROPN'),
#  (@nike, 'VBP', 'VERB'),
#  (..., ':', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (787, 'CD', 'NUM'),
#  (    , '_SP', 'SPACE'),
#  (“, '``', 'PUNCT'),
#  (Do, 'VB', 'AUX'),
#  (n’t, 'RB', 'PART'),
#  (ask, 'VB', 'VERB'),
#  (if, 'IN', 'SCONJ'),
#  (your, 'PRP$', 'DET'),
#  (dreams, 'NNS', 'NOUN'),
#  (are, 'VBP', 'AUX'),
#  (crazy, 'JJ', 'ADJ'),
#  (,, ',', 'PUNCT'),
#  (ask, 'VB', 'VERB'),
#  (if, 'IN', 'SCONJ'),
#  (it, 'PRP', 'PRON'),
#  (..., ':', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (1149, 'CD', 'NUM'),
#  (   , '_SP', 'SPACE'),
#  (@Nike, 'UH', 'INTJ'),
#  (Hire, 'VB', 'VERB'),
#  (a, 'DT', 'DET'),
#  (worthless, 'JJ', 'ADJ'),
#  (,, ',', 'PUNCT'),
#  (no, 'DT', 'DET'),
#  (talent, 'NN', 'NOUN'),
#  (., '.', 'PUNCT'),
#  (America, 'NNP', 'PROPN'),
#  (hat, 'NN', 'NOUN'),
#  (..., ':', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (838, 'CD', 'NUM'),
#  (    , '_SP', 'SPACE'),
#  (kudos, 'NNS', 'NOUN'),
#  (to, 'IN', 'ADP'),
#  (#, 'NNP', 'PROPN'),
#  (Nike, 'NNP', 'PROPN'),
#  (for, 'IN', 'ADP'),
#  (realizing, 'VBG', 'VERB'),
#  (#, '$', 'SYM'),
#  (ColinKaepernick, 'NNP', 'PROPN'),
#  (..., ':', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (3356, 'CD', 'NUM'),
#  (   , '_SP', 'SPACE'),
#  (Self, 'NNP', 'PROPN'),
#  (LOVE, 'NNP', 'PROPN'),
#  (and, 'CC', 'CCONJ'),
#  (Self, 'NNP', 'PROPN'),
#  (DISCIPLINE, 'NNP', 'PROPN'),
#  (means, 'VBZ', 'VERB'),
#  (you, 'PRP', 'PRON'),
#  (forgo, 'VBP', 'VERB'),
#  (..., ':', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (1271, 'CD', 'NUM'),
#  (   , '_SP', 'SPACE'),
#  (Why, 'WRB', 'ADV'),
#  (does, 'VBZ', 'AUX'),
#  (n’t, 'RB', 'PART'),
#  (the, 'DT', 'DET'),
#  (“, '``', 'PUNCT'),
#  (Anonymous”author, 'NN', 'NOUN'),
#  (of, 'IN', 'ADP'),
#  (the, 'DT', 'DET'),
#  (#, '$', 'SYM'),
#  (Fail, 'NNP', 'PROPN'),
#  (..., ':', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (3574, 'CD', 'NUM'),
#  (         , '_SP', 'SPACE'),
#  (Matt, 'NNP', 'PROPN'),
#  (Ryan, 'NNP', 'PROPN'),
#  (throw, 'VB', 'VERB'),
#  (it, 'PRP', 'PRON'),
#  (to, 'IN', 'ADP'),
#  (Julio, 'NNP', 'PROPN'),
#  (#, 'NNP', 'PROPN'),
#  (JustDoIt, 'NNP', 'PROPN'),
#  (#, 'NN', 'NOUN'),
#  (Nike, 'NNP', 'PROPN'),
#  (, '_SP', 'SPACE'),
#  (3883, 'CD', 'NUM'),
#  (   , '_SP', 'SPACE'),
#  (There, 'RB', 'ADV'),
#  (it, 'PRP', 'PRON'),
#  (go, 'VBP', 'VERB'),
#  (!, '.', 'PUNCT'),
#  (!, '.', 'PUNCT'),
#  (!, '.', 'PUNCT'),
#  (!, '.', 'PUNCT'),
#  (!, '.', 'PUNCT'),
#  (!, '.', 'PUNCT'),
#  (!, '.', 'PUNCT'),
#  (Now, 'RB', 'ADV'),
#  (I, 'PRP', 'PRON'),
#  (can, 'MD', 'VERB'),
#  (stop, 'VB', 'VERB'),
#  (watching, 'VBG', 'VERB'),
#  (the, 'DT', 'DET'),
#  (..., ':', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (3656, 'CD', 'NUM'),
#  (   , '_SP', 'SPACE'),
#  (@Nike, 'JJ', 'ADJ'),
#  (“, '``', 'PUNCT'),
#  (stand, 'NN', 'NOUN'),
#  (for, 'IN', 'ADP'),
#  (something, 'NN', 'PRON'),
#  (”, "''", 'PUNCT'),
#  (it, 'PRP', 'PRON'),
#  (is, 'VBZ', 'AUX'),
#  (called, 'VBN', 'VERB'),
#  (the, 'DT', 'DET'),
#  (F, 'NNP', 'PROPN'),
#  (..., ':', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (4301, 'CD', 'NUM'),
#  (   , '_SP', 'SPACE'),
#  (✊, 'NFP', 'PUNCT'),
#  (🏾, 'JJ', 'ADJ'),
#  (#, 'NNP', 'PROPN'),
#  (Repost, 'NNP', 'PROPN'),
#  (mgnm_opus\n・・・\n, 'NNP', 'PROPN'),
#  (👑, 'IN', 'ADP'),
#  (This, 'DT', 'DET'),
#  (message, 'NN', 'NOUN'),
#  (is, 'VBZ', 'AUX'),
#  (a, 'DT', 'DET'),
#  (..., ':', 'PUNCT'),
#  (, '_SP', 'SPACE'),
#  (Name, 'NN', 'NOUN'),
#  (:, ':', 'PUNCT'),
#  (tweet_full_text, 'JJ', 'ADJ'),
#  (,, ',', 'PUNCT'),
#  (dtype, 'NN', 'NOUN'),
#  (:, ':', 'PUNCT'),
#  (object, 'NN', 'NOUN')]

# %%
[i for i in pos_tag if i[1] == 'POS']
# Out:
# []

# %% [markdown]
# #### No 'POS' tags in our data so we do not have the option to exploit the owner and the possession information.

# %%
[j for j in pos_tag if j[2] == 'PART']
# Out:
# [(to, 'TO', 'PART'),
#  (n’t, 'RB', 'PART'),
#  (n't, 'RB', 'PART'),
#  (to, 'TO', 'PART'),
#  (n’t, 'RB', 'PART'),
#  (n’t, 'RB', 'PART')]

# %% [markdown]
# #### 'PART' tag suggests that these words are parts of the previous words.

# %% [markdown]
# ### Noun chunks in the data

# %%
nouns = list(doc.noun_chunks)
nouns
# Out:
# [your dream, @Nike, #JustDoIt
#  3191    Question, you, a white person, Nik, We, the FISA appl, #justdoit, your focus America, #JustDoIt, a number, people, Falcons Eagles, #Football, #JustDoIt, #ATLvsPH, @Reuters, the WH distraction, #Imp, Trump, Congress, My brand, your dreams, if it, a worthless, no talent, America hat, 838     kudos, #Nike, #ColinKaepernick, Self LOVE, Self DISCIPLINE, you, the #Fail, Matt Ryan, it, Julio #JustDoIt #Nike, it, I, stand, something, it, 🏾 #, Repost mgnm_opus\n・・・\n, This message, a...
#  Name, dtype, : object]

# %% [markdown]
# ### Syntactic dependency between tokens

# %%
[(token, token.dep_) for token in doc]
# Out:
# [(157, 'nsubj'),
#  (    , ''),
#  (Never, 'neg'),
#  (stop, 'ROOT'),
#  (moving, 'xcomp'),
#  (., 'punct'),
#  (\n\nDon’t, 'nsubj'),
#  (ask, 'ROOT'),
#  (if, 'prep'),
#  (your, 'poss'),
#  (dream, 'pobj'),
#  (..., 'punct'),
#  (, ''),
#  (3961, 'ROOT'),
#  (               , ''),
#  (@Nike, 'ROOT'),
#  (what, 'det'),
#  (an, 'det'),
#  (inspiring, 'amod'),
#  (ad, 'ccomp'),
#  (., 'punct'),
#  (#, 'dep'),
#  (JustDoIt, 'npadvmod'),
#  (, ''),
#  (3191, 'nummod'),
#  (   , ''),
#  (Question, 'ROOT'),
#  (if, 'mark'),
#  (you, 'nsubj'),
#  (see, 'advcl'),
#  (a, 'det'),
#  (white, 'amod'),
#  (person, 'dobj'),
#  (wearing, 'acl'),
#  (Nik, 'dobj'),
#  (..., 'punct'),
#  (, ''),
#  (2648, 'ROOT'),
#  (   , ''),
#  (@Jim_Jordan, 'ROOT'),
#  (We, 'nsubj'),
#  (would, 'aux'),
#  (love, 'ROOT'),
#  (to, 'aux'),
#  (see, 'xcomp'),
#  (the, 'det'),
#  (FISA, 'compound'),
#  (appl, 'dobj'),
#  (..., 'punct'),
#  (, ''),
#  (4259, 'ROOT'),
#  (   , ''),
#  (✊, 'punct'),
#  (🏾#nike, 'ROOT'),
#  (#, 'nmod'),
#  (justdoit, 'nsubj'),
#  (\nNike, 'intj'),
#  (probably, 'advmod'),
#  (does, 'aux'),
#  (n’t, 'neg'),
#  (care, 'ROOT'),
#  (..., 'punct'),
#  (, ''),
#  (823, 'nsubj'),
#  (    , ''),
#  (Change, 'ROOT'),
#  (your, 'poss'),
#  (focus, 'compound'),
#  (America, 'dobj'),
#  (., 'punct'),
#  (#, 'dep'),
#  (JustDoIt, 'ROOT'),
#  (https://t, 'punct'),
#  (..., 'punct'),
#  (, ''),
#  (3647, 'ROOT'),
#  (   , ''),
#  (There, 'expl'),
#  (will, 'aux'),
#  (be, 'ROOT'),
#  (a, 'det'),
#  (number, 'attr'),
#  (of, 'prep'),
#  (people, 'pobj'),
#  (that, 'nsubj'),
#  (see, 'relcl'),
#  (the, 'dobj'),
#  (..., 'punct'),
#  (, ''),
#  (4202, 'ROOT'),
#  (   , ''),
#  (Falcons, 'compound'),
#  (Eagles, 'ROOT'),
#  ( , ''),
#  (#, 'nmod'),
#  (Football, 'ROOT'),
#  ( , ''),
#  (#, 'dep'),
#  (JustDoIt, 'ROOT'),
#  ( , ''),
#  (#, 'nmod'),
#  (ATLvsPH, 'appos'),
#  (..., 'punct'),
#  (, ''),
#  (2998, 'appos'),
#  (   , ''),
#  (@Reuters, 'appos'),
#  (Here, 'advmod'),
#  (comes, 'ROOT'),
#  (the, 'det'),
#  (WH, 'compound'),
#  (distraction, 'nsubj'),
#  (., 'punct'),
#  (  , ''),
#  (#, 'compound'),
#  (Imp, 'ROOT'),
#  (..., 'punct'),
#  (, ''),
#  (3022, 'ROOT'),
#  (   , ''),
#  (Coulter, 'dep'),
#  (:, 'punct'),
#  (Trump, 'nsubj'),
#  (does, 'aux'),
#  (n't, 'neg'),
#  (need, 'ROOT'),
#  (Congress, 'nsubj'),
#  (to, 'aux'),
#  (build, 'ccomp'),
#  (..., 'punct'),
#  (, ''),
#  (3182, 'ROOT'),
#  (   , ''),
#  (My, 'poss'),
#  (brand, 'nsubj'),
#  (new, 'amod'),
#  (@Nikecourt, 'compound'),
#  (Air, 'compound'),
#  (Zoom, 'compound'),
#  (Vapor, 'intj'),
#  (X, 'compound'),
#  (@nike, 'ROOT'),
#  (..., 'punct'),
#  (, ''),
#  (787, 'ROOT'),
#  (    , ''),
#  (“, 'punct'),
#  (Do, 'aux'),
#  (n’t, 'neg'),
#  (ask, 'ROOT'),
#  (if, 'mark'),
#  (your, 'poss'),
#  (dreams, 'nsubj'),
#  (are, 'ccomp'),
#  (crazy, 'acomp'),
#  (,, 'punct'),
#  (ask, 'dep'),
#  (if, 'mark'),
#  (it, 'dobj'),
#  (..., 'punct'),
#  (, ''),
#  (1149, 'ROOT'),
#  (   , ''),
#  (@Nike, 'advmod'),
#  (Hire, 'ROOT'),
#  (a, 'det'),
#  (worthless, 'amod'),
#  (,, 'punct'),
#  (no, 'det'),
#  (talent, 'dobj'),
#  (., 'punct'),
#  (America, 'compound'),
#  (hat, 'ROOT'),
#  (..., 'punct'),
#  (, ''),
#  (838, 'nummod'),
#  (    , ''),
#  (kudos, 'ROOT'),
#  (to, 'prep'),
#  (#, 'compound'),
#  (Nike, 'pobj'),
#  (for, 'prep'),
#  (realizing, 'pcomp'),
#  (#, 'compound'),
#  (ColinKaepernick, 'dobj'),
#  (..., 'punct'),
#  (, ''),
#  (3356, 'ROOT'),
#  (   , ''),
#  (Self, 'compound'),
#  (LOVE, 'nsubj'),
#  (and, 'cc'),
#  (Self, 'compound'),
#  (DISCIPLINE, 'conj'),
#  (means, 'ROOT'),
#  (you, 'nsubj'),
#  (forgo, 'ccomp'),
#  (..., 'punct'),
#  (, ''),
#  (1271, 'ROOT'),
#  (   , ''),
#  (Why, 'advmod'),
#  (does, 'ROOT'),
#  (n’t, 'neg'),
#  (the, 'det'),
#  (“, 'punct'),
#  (Anonymous”author, 'npadvmod'),
#  (of, 'prep'),
#  (the, 'det'),
#  (#, 'nmod'),
#  (Fail, 'pobj'),
#  (..., 'punct'),
#  (, ''),
#  (3574, 'ROOT'),
#  (         , ''),
#  (Matt, 'compound'),
#  (Ryan, 'nsubj'),
#  (throw, 'ROOT'),
#  (it, 'dobj'),
#  (to, 'prep'),
#  (Julio, 'compound'),
#  (#, 'dep'),
#  (JustDoIt, 'nmod'),
#  (#, 'nmod'),
#  (Nike, 'pobj'),
#  (, ''),
#  (3883, 'ROOT'),
#  (   , ''),
#  (There, 'advmod'),
#  (it, 'nsubj'),
#  (go, 'ROOT'),
#  (!, 'punct'),
#  (!, 'punct'),
#  (!, 'punct'),
#  (!, 'punct'),
#  (!, 'punct'),
#  (!, 'punct'),
#  (!, 'punct'),
#  (Now, 'advmod'),
#  (I, 'nsubj'),
#  (can, 'aux'),
#  (stop, 'ROOT'),
#  (watching, 'xcomp'),
#  (the, 'dobj'),
#  (..., 'punct'),
#  (, ''),
#  (3656, 'ROOT'),
#  (   , ''),
#  (@Nike, 'ROOT'),
#  (“, 'punct'),
#  (stand, 'ROOT'),
#  (for, 'prep'),
#  (something, 'pobj'),
#  (”, 'punct'),
#  (it, 'nsubjpass'),
#  (is, 'auxpass'),
#  (called, 'ROOT'),
#  (the, 'det'),
#  (F, 'oprd'),
#  (..., 'punct'),
#  (, ''),
#  (4301, 'ROOT'),
#  (   , ''),
#  (✊, 'ROOT'),
#  (🏾, 'compound'),
#  (#, 'ROOT'),
#  (Repost, 'compound'),
#  (mgnm_opus\n・・・\n, 'ROOT'),
#  (👑, 'npadvmod'),
#  (This, 'det'),
#  (message, 'nsubj'),
#  (is, 'ROOT'),
#  (a, 'det'),
#  (..., 'punct'),
#  (, ''),
#  (Name, 'attr'),
#  (:, 'punct'),
#  (tweet_full_text, 'ROOT'),
#  (,, 'punct'),
#  (dtype, 'appos'),
#  (:, 'punct'),
#  (object, 'appos')]

# %% [markdown]
# ## Named Entity Recognition

# %%
[i for i in doc.ents]
# Out:
# [157,
#  3961,
#  3191,
#  Nik,
#  2648,
#  FISA,
#  4259,
#  justdoit,
#  823,
#  America,
#  3647,
#  4202,
#  Falcons Eagles,
#  Football,
#  ATLvsPH,
#  2998,
#  Imp,
#  3022,
#  Trump,
#  Congress,
#  3182,
#  787,
#  Don’t ask if your dreams are crazy, ask if it...,
#  1149,
#  America,
#  838,
#  Nike,
#  ColinKaepernick,
#  3356,
#  LOVE,
#  1271,
#  3574,
#  Matt Ryan,
#  Julio #JustDoIt,
#  Nike,
#  3883,
#  3656,
#  F,
#  4301,
#  Repost]

# %% [markdown]
# ### Entities alongwith their labels

# %%
[(i, i.label_, i.label) for i in doc.ents]
# Out:
# [(157, 'CARDINAL', 397),
#  (3961, 'CARDINAL', 397),
#  (3191, 'DATE', 391),
#  (Nik, 'PERSON', 380),
#  (2648, 'DATE', 391),
#  (FISA, 'ORG', 383),
#  (4259, 'DATE', 391),
#  (justdoit, 'PERSON', 380),
#  (823, 'CARDINAL', 397),
#  (America, 'GPE', 384),
#  (3647, 'DATE', 391),
#  (4202, 'CARDINAL', 397),
#  (Falcons Eagles, 'ORG', 383),
#  (Football, 'PERSON', 380),
#  (ATLvsPH, 'MONEY', 394),
#  (2998, 'DATE', 391),
#  (Imp, 'MONEY', 394),
#  (3022, 'DATE', 391),
#  (Trump, 'PRODUCT', 386),
#  (Congress, 'ORG', 383),
#  (3182, 'DATE', 391),
#  (787, 'CARDINAL', 397),
#  (Don’t ask if your dreams are crazy, ask if it..., 'WORK_OF_ART', 388),
#  (1149, 'DATE', 391),
#  (America, 'GPE', 384),
#  (838, 'CARDINAL', 397),
#  (Nike, 'MONEY', 394),
#  (ColinKaepernick, 'PERSON', 380),
#  (3356, 'DATE', 391),
#  (LOVE, 'ORG', 383),
#  (1271, 'DATE', 391),
#  (3574, 'DATE', 391),
#  (Matt Ryan, 'PERSON', 380),
#  (Julio #JustDoIt, 'ORG', 383),
#  (Nike, 'PERSON', 380),
#  (3883, 'DATE', 391),
#  (3656, 'DATE', 391),
#  (F, 'PRODUCT', 386),
#  (4301, 'DATE', 391),
#  (Repost, 'PERSON', 380)]

# %% [markdown]
# ### Visualizing named entities alongwith labels

# %%
#named entities along with text labels
spacy.displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     157
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      Never stop moving. \n\nDon’t ask if your dream...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3961
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#                 @Nike what an inspiring ad. #JustDoIt</br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3191
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#     Question if you see a white person wearing
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nik
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ...</br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2648
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#     @Jim_Jordan We would love to see the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FISA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  appl...</br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4259
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#     ✊🏾#nike #
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     justdoit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  \nNike probably doesn’t care...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     823
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      Change your focus
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . #JustDoIt https://t...</br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3647
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#     There will be a number of people that see the ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4202
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Falcons Eagles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#   #
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Football
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#   #JustDoIt  #
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ATLvsPH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ...</br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2998
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#     @Reuters Here comes the WH distraction.   #
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Imp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ...</br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#     Coulter:
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  doesn't need
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Congress
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to build ...</br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3182
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#     My brand new @Nikecourt Air Zoom Vapor X @nike...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     787
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      “
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1;

# %% [markdown]
# ### Dependency Parser Visualization

# %%
spacy.displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f423cb11d3974e388129de40c1fc7b81-0" class="displacy" width="40125" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">157</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">    </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Never</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">stop</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">moving.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">\n\nDon’t</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">ask</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">if</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">dream...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">3961</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">               </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">@Nike</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">what</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">inspiring</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">ad. #</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">JustDoIt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">3191</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">   </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">Question</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">if</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">see</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">white</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">person</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">wearing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">Nik...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="curr
